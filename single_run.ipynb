# %%
import importlib
import configuration
import functions

importlib.reload(configuration)
importlib.reload(functions)

# %run main.py
# Out:
# LHAPDF 6.5.5 loading /hepusers2/fuscomus/miniconda3/envs/DRToM/share/LHAPDF/cteq6l1/cteq6l1_0000.dat
# cteq6l1 PDF set, member #0, version 4; LHAPDF ID = 10042
#
# Running 2 → 4 PS with 10 events.
# Active subprocesses: gg → gg, gg → qq̄, gq → gq, gq̄ → gq̄, qq → qq, qq' → qq', q̄q̄ → q̄q̄, q̄q̄' → q̄q̄', qq̄' → qq̄', qq̄ → gg, qq̄ → qq̄, qq̄ → q'q̄'
#
# Creating events with dimensionality = 3D
# ⬤ Starting 2.0to2.1 TeV
# ✔ Finished 2.00–2.10 TeV | Events: 10 | Failures: 0
# ⬤ Starting 2.1to2.2 TeV
# ✔ Finished 2.10–2.20 TeV | Events: 10 | Failures: 0
# ⬤ Starting 2.2to2.3 TeV
# ✔ Finished 2.20–2.30 TeV | Events: 10 | Failures: 0
# ⬤ Starting 2.3to2.4 TeV
# ✔ Finished 2.30–2.40 TeV | Events: 10 | Failures: 0
# ⬤ Starting 2.4to2.5 TeV
# ✔ Finished 2.40–2.50 TeV | Events: 10 | Failures: 0
# ⬤ Starting 2.5to2.6 TeV
# ✔ Finished 2.50–2.60 TeV | Events: 10 | Failures: 0
# ⬤ Starting 2.6to2.7 TeV
# ✔ Finished 2.60–2.70 TeV | Events: 10 | Failures: 0
# ⬤ Starting 2.7to2.8 TeV
# ...
